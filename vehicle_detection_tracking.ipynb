# %%
import cv2
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
from ultralytics import YOLO
from scipy.spatial import distance
import math

cv2.destroyAllWindows()

# Load YOLOv8 model
model = YOLO("yolov8n.pt")
video_path = "video_compressed.mp4"
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print("Error: Unable to open video file.")
    exit()

# Get video dimensions
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Create a named window (no resizing, original size is maintained)
cv2.namedWindow("Vehicle Detection and Tracking", cv2.WINDOW_NORMAL)

# Mapping scale for real-world dimensions (calibration scale factor)
scale_factor = 0.05  # Adjust based on calibration (pixel to meter ratio)

def map_pixel_to_real_world(pixel_distance, scale_factor):
    return pixel_distance * scale_factor

# Preprocessing function (resizing, noise reduction, perspective transformation)
def preprocess_frame(frame):
    # Resize the frame if necessary (optional)
    frame_resized = cv2.resize(frame, (frame_width, frame_height))
    
    # Apply Gaussian Blur for noise reduction
    frame_blurred = cv2.GaussianBlur(frame_resized, (5, 5), 0)

    # Perspective Transformation (bird's-eye view)
    # Define source and destination points for perspective transformation
    src_pts = np.float32([[100, frame_height], [frame_width - 100, frame_height], [300, 200], [frame_width - 300, 200]])
    dst_pts = np.float32([[0, frame_height], [frame_width, frame_height], [0, 0], [frame_width, 0]])

    matrix = cv2.getPerspectiveTransform(src_pts, dst_pts)
    frame_perspective = cv2.warpPerspective(frame_blurred, matrix, (frame_width, frame_height))

    return frame_perspective

# Define regions (manually divide based on video structure)
road_regions = [
    {'name': 'Road 1', 'x1': 0, 'x2': int(frame_width / 5), 'y1': 0, 'y2': int(2 * frame_height / 4), 'color': (0, 255, 0), 'y_offset': 50},  # Left third
    {'name': 'Road 2', 'x1': int(frame_width / 5), 'x2': int(4 * frame_width / 5), 'y1': int(2 * (frame_height / 4)), 'y2': frame_height, 'color': (0, 0, 255), 'y_offset': 150},  # Middle third
    {'name': 'Road 3', 'x1': int(3 * frame_width / 5), 'x2': frame_width, 'y1': 0, 'y2': int(frame_height / 2), 'color': (255, 0, 0), 'y_offset': 250}  # Right third
]

# Vehicle dimensions (e.g., average width of cars and trucks in meters)
vehicle_widths = {'car': 2.0, 'truck': 2.5}  # Example values

frame_counter = 0  # Frame counter to log results frame by frame

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("End of video or unable to read frame.")
        break

    frame_counter += 1  # Increment frame counter

    # Preprocess the frame (resize, noise reduction, perspective transformation)
    processed_frame = preprocess_frame(frame)

    # Perform object detection
    results = model.predict(processed_frame)
    detections = []

    for result in results:
        for box in result.boxes.data:
            x1, y1, x2, y2, conf, cls = box.tolist()
            if int(cls) in [2, 7]:  # Detect cars and trucks (class 2 and 7)
                detections.append([int(x1), int(y1), int(x2), int(y2), conf])

    # Initialize list to store centroids and detected vehicles for each road
    road_widths = []

    # Process each road region
    for road in road_regions:
        # Extract the region of the frame for this road
        road_frame = processed_frame[road['y1']:road['y2'], road['x1']:road['x2']]

        centroids = []
        for det in detections:
            x1, y1, x2, y2, conf = det
            # Check if the detection is within the current road's x boundaries and y boundaries
            if road['x1'] <= x1 < road['x2'] and road['y1'] <= y1 < road['y2']:  
                cx = int((x1 + x2) / 2)
                cy = int((y1 + y2) / 2)
                centroids.append((cx, cy))
                # Draw rectangle around detected object
                cv2.rectangle(frame, (x1, y1), (x2, y2), road['color'], 2)
                # Draw centroid point
                cv2.circle(frame, (cx, cy), 5, (255, 255, 255), -1)

        # Calculate width for the road (the horizontal distance between centroids in the region)
        road_width = 0
        if len(centroids) > 1:
            farthest_distance = 0
            farthest_points = (None, None)
            for i, c1 in enumerate(centroids):
                for c2 in centroids[i + 1:]:
                    pixel_dist = distance.euclidean(c1, c2)
                    if pixel_dist > farthest_distance:
                        farthest_distance = pixel_dist
                        farthest_points = (c1, c2)

            # Calculate real-world distance from pixel distance
            real_distance = map_pixel_to_real_world(farthest_distance, scale_factor)
            road_width = real_distance

            if farthest_points[0] and farthest_points[1]:
                cv2.line(frame, farthest_points[0], farthest_points[1], road['color'], 2)
                # Display width on the frame
                cv2.putText(frame, f"{road['name']} Width: {road_width:.2f}m", 
                            (1, road['y_offset']), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)

        # Highlight the road region in the specified color
        cv2.rectangle(frame, (road['x1'], road['y1']), (road['x2'], road['y2']), road['color'], 2)

        # Store the road width for each frame
        road_widths.append((road['name'], road_width))

    # Save the frame results to the text file
    with open("road_width_results.txt", "a") as f:
        f.write(f"Frame {frame_counter}:\n")
        for road_name, width in road_widths:
            f.write(f"  {road_name}: {width:.2f} meters\n")
        f.write("\n")

    # Display the video frame without resizing (maintaining original size)
    cv2.imshow("Vehicle Detection and Tracking", frame)

    # Exit on pressing 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 7 cars, 166.9ms
# Speed: 5.0ms preprocess, 166.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 186.0ms
# Speed: 4.6ms preprocess, 186.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 141.2ms
# Speed: 5.3ms preprocess, 141.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 171.7ms
# Speed: 6.0ms preprocess, 171.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 105.2ms
# Speed: 4.0ms preprocess, 105.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 115.2ms
# Speed: 4.7ms preprocess, 115.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 105.9ms
# Speed: 3.0ms preprocess, 105.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 99.9ms
# Speed: 4.1ms preprocess, 99.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 104.0ms
# Speed: 3.5ms preprocess, 104.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 127.8ms
# Speed: 2.5ms preprocess, 127.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 142.9ms
# Speed: 4.1ms preprocess, 142.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 101.1ms
# Speed: 4.0ms preprocess, 101.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 101.9ms
# Speed: 3.0ms preprocess, 101.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 111.1ms
# Speed: 3.2ms preprocess, 111.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 111.2ms
# Speed: 2.6ms preprocess, 111.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 98.9ms
# Speed: 4.0ms preprocess, 98.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 126.0ms
# Speed: 3.0ms preprocess, 126.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 101.1ms
# Speed: 3.1ms preprocess, 101.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 102.9ms
# Speed: 3.0ms preprocess, 102.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 98.1ms
# Speed: 4.1ms preprocess, 98.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 104.7ms
# Speed: 3.1ms preprocess, 104.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 91.1ms
# Speed: 3.5ms preprocess, 91.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 101.3ms
# Speed: 2.4ms preprocess, 101.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 99.6ms
# Speed: 4.0ms preprocess, 99.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 137.7ms
# Speed: 3.6ms preprocess, 137.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 144.7ms
# Speed: 4.2ms preprocess, 144.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 146.8ms
# Speed: 3.0ms preprocess, 146.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 138.4ms
# Speed: 5.2ms preprocess, 138.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 99.9ms
# Speed: 4.0ms preprocess, 99.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 98.2ms
# Speed: 4.1ms preprocess, 98.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 96.2ms
# Speed: 3.0ms preprocess, 96.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 118.0ms
# Speed: 3.0ms preprocess, 118.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 102.8ms
# Speed: 3.0ms preprocess, 102.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 98.2ms
# Speed: 3.0ms preprocess, 98.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 99.0ms
# Speed: 4.1ms preprocess, 99.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 103.7ms
# Speed: 3.0ms preprocess, 103.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 98.0ms
# Speed: 3.0ms preprocess, 98.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 98.7ms
# Speed: 3.5ms preprocess, 98.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 98.6ms
# Speed: 4.1ms preprocess, 98.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 110.2ms
# Speed: 3.0ms preprocess, 110.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 137.5ms
# Speed: 3.5ms preprocess, 137.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 98.2ms
# Speed: 3.0ms preprocess, 98.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 102.3ms
# Speed: 2.0ms preprocess, 102.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 101.3ms
# Speed: 3.0ms preprocess, 101.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 95.1ms
# Speed: 4.1ms preprocess, 95.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 87.8ms
# Speed: 2.7ms preprocess, 87.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 88.4ms
# Speed: 2.6ms preprocess, 88.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 91.2ms
# Speed: 4.1ms preprocess, 91.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 85.1ms
# Speed: 3.2ms preprocess, 85.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 89.6ms
# Speed: 2.5ms preprocess, 89.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 88.2ms
# Speed: 3.0ms preprocess, 88.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 87.9ms
# Speed: 3.0ms preprocess, 87.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 105.9ms
# Speed: 4.0ms preprocess, 105.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 83.3ms
# Speed: 2.0ms preprocess, 83.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 122.5ms
# Speed: 3.6ms preprocess, 122.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 91.1ms
# Speed: 3.5ms preprocess, 91.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 88.5ms
# Speed: 3.3ms preprocess, 88.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 97.6ms
# Speed: 2.0ms preprocess, 97.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 87.2ms
# Speed: 2.1ms preprocess, 87.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 87.9ms
# Speed: 3.3ms preprocess, 87.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 93.0ms
# Speed: 4.1ms preprocess, 93.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 123.8ms
# Speed: 2.0ms preprocess, 123.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 86.7ms
# Speed: 2.0ms preprocess, 86.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 88.6ms
# Speed: 2.0ms preprocess, 88.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 98.6ms
# Speed: 3.0ms preprocess, 98.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 87.9ms
# Speed: 3.0ms preprocess, 87.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 93.8ms
# Speed: 2.0ms preprocess, 93.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 88.0ms
# Speed: 2.6ms preprocess, 88.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 87.3ms
# Speed: 2.6ms preprocess, 87.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 131.1ms
# Speed: 3.1ms preprocess, 131.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 102.9ms
# Speed: 2.0ms preprocess, 102.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 83.2ms
# Speed: 3.0ms preprocess, 83.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 88.9ms
# Speed: 2.0ms preprocess, 88.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 96.6ms
# Speed: 3.0ms preprocess, 96.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 92.2ms
# Speed: 3.1ms preprocess, 92.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 88.1ms
# Speed: 3.1ms preprocess, 88.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 87.8ms
# Speed: 2.6ms preprocess, 87.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 94.8ms
# Speed: 3.1ms preprocess, 94.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 87.1ms
# Speed: 3.6ms preprocess, 87.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 83.3ms
# Speed: 3.0ms preprocess, 83.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 87.6ms
# Speed: 2.0ms preprocess, 87.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 87.0ms
# Speed: 2.2ms preprocess, 87.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 91.1ms
# Speed: 3.0ms preprocess, 91.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 90.2ms
# Speed: 2.0ms preprocess, 90.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 87.1ms
# Speed: 3.0ms preprocess, 87.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 86.2ms
# Speed: 3.1ms preprocess, 86.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 88.5ms
# Speed: 2.0ms preprocess, 88.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 86.5ms
# Speed: 3.5ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 83.7ms
# Speed: 2.0ms preprocess, 83.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 86.4ms
# Speed: 2.0ms preprocess, 86.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 85.6ms
# Speed: 3.8ms preprocess, 85.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 90.3ms
# Speed: 4.1ms preprocess, 90.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 118.1ms
# Speed: 2.0ms preprocess, 118.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 105.9ms
# Speed: 4.1ms preprocess, 105.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 90.2ms
# Speed: 2.0ms preprocess, 90.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 95.5ms
# Speed: 2.1ms preprocess, 95.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 88.1ms
# Speed: 2.5ms preprocess, 88.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 88.6ms
# Speed: 1.0ms preprocess, 88.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 86.1ms
# Speed: 3.1ms preprocess, 86.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 93.2ms
# Speed: 2.1ms preprocess, 93.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 85.1ms
# Speed: 3.0ms preprocess, 85.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 88.9ms
# Speed: 2.0ms preprocess, 88.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 88.0ms
# Speed: 4.1ms preprocess, 88.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 85.5ms
# Speed: 3.1ms preprocess, 85.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 95.1ms
# Speed: 2.0ms preprocess, 95.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 112.5ms
# Speed: 2.0ms preprocess, 112.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 105.2ms
# Speed: 4.1ms preprocess, 105.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 87.6ms
# Speed: 2.0ms preprocess, 87.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 93.2ms
# Speed: 3.0ms preprocess, 93.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 87.6ms
# Speed: 2.1ms preprocess, 87.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 83.3ms
# Speed: 3.0ms preprocess, 83.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 85.9ms
# Speed: 3.1ms preprocess, 85.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 90.0ms
# Speed: 2.6ms preprocess, 90.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 86.0ms
# Speed: 3.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 87.2ms
# Speed: 4.0ms preprocess, 87.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 84.8ms
# Speed: 3.0ms preprocess, 84.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 86.5ms
# Speed: 3.0ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 112.0ms
# Speed: 3.0ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 126.7ms
# Speed: 3.0ms preprocess, 126.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 95.2ms
# Speed: 4.1ms preprocess, 95.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 80.8ms
# Speed: 3.0ms preprocess, 80.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 96.8ms
# Speed: 2.0ms preprocess, 96.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 95.6ms
# Speed: 1.5ms preprocess, 95.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 93.1ms
# Speed: 2.0ms preprocess, 93.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 86.7ms
# Speed: 3.0ms preprocess, 86.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 89.7ms
# Speed: 3.6ms preprocess, 89.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 93.3ms
# Speed: 3.6ms preprocess, 93.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 88.0ms
# Speed: 2.1ms preprocess, 88.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 85.7ms
# Speed: 3.7ms preprocess, 85.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 laptop, 86.4ms
# Speed: 3.0ms preprocess, 86.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 laptop, 94.7ms
# Speed: 3.0ms preprocess, 94.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 118.6ms
# Speed: 2.0ms preprocess, 118.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 135.5ms
# Speed: 2.5ms preprocess, 135.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 132.3ms
# Speed: 5.0ms preprocess, 132.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 89.2ms
# Speed: 2.0ms preprocess, 89.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 89.0ms
# Speed: 2.0ms preprocess, 89.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 89.9ms
# Speed: 3.1ms preprocess, 89.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 81.9ms
# Speed: 3.1ms preprocess, 81.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 93.1ms
# Speed: 3.1ms preprocess, 93.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 87.2ms
# Speed: 2.0ms preprocess, 87.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 88.2ms
# Speed: 3.0ms preprocess, 88.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 88.5ms
# Speed: 3.6ms preprocess, 88.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 95.2ms
# Speed: 2.5ms preprocess, 95.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 90.9ms
# Speed: 2.0ms preprocess, 90.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 85.5ms
# Speed: 2.5ms preprocess, 85.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 86.9ms
# Speed: 2.0ms preprocess, 86.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 87.2ms
# Speed: 2.1ms preprocess, 87.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 91.2ms
# Speed: 3.0ms preprocess, 91.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 89.3ms
# Speed: 2.0ms preprocess, 89.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 83.2ms
# Speed: 2.6ms preprocess, 83.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 87.2ms
# Speed: 2.5ms preprocess, 87.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 92.1ms
# Speed: 2.6ms preprocess, 92.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 96.7ms
# Speed: 2.7ms preprocess, 96.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 112.0ms
# Speed: 3.0ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 104.0ms
# Speed: 3.1ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 92.2ms
# Speed: 3.0ms preprocess, 92.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 88.2ms
# Speed: 2.5ms preprocess, 88.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 118.1ms
# Speed: 2.0ms preprocess, 118.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 127.7ms
# Speed: 7.4ms preprocess, 127.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 95.4ms
# Speed: 2.4ms preprocess, 95.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 94.7ms
# Speed: 4.0ms preprocess, 94.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 88.0ms
# Speed: 2.8ms preprocess, 88.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 90.6ms
# Speed: 3.1ms preprocess, 90.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 102.3ms
# Speed: 2.5ms preprocess, 102.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 91.2ms
# Speed: 3.1ms preprocess, 91.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 85.4ms
# Speed: 2.5ms preprocess, 85.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 94.2ms
# Speed: 4.0ms preprocess, 94.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 101.4ms
# Speed: 2.6ms preprocess, 101.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 93.3ms
# Speed: 3.6ms preprocess, 93.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 94.9ms
# Speed: 2.1ms preprocess, 94.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 92.3ms
# Speed: 2.0ms preprocess, 92.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 86.0ms
# Speed: 3.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 145.8ms
# Speed: 2.5ms preprocess, 145.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 194.0ms
# Speed: 2.0ms preprocess, 194.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 83.0ms
# Speed: 3.1ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 135.0ms
# Speed: 2.0ms preprocess, 135.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 106.5ms
# Speed: 3.6ms preprocess, 106.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 95.0ms
# Speed: 4.0ms preprocess, 95.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 92.9ms
# Speed: 3.0ms preprocess, 92.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 130.7ms
# Speed: 5.1ms preprocess, 130.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 98.0ms
# Speed: 2.0ms preprocess, 98.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 107.7ms
# Speed: 3.1ms preprocess, 107.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 100.1ms
# Speed: 3.0ms preprocess, 100.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 101.9ms
# Speed: 3.1ms preprocess, 101.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 89.8ms
# Speed: 2.0ms preprocess, 89.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 101.7ms
# Speed: 3.0ms preprocess, 101.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 118.9ms
# Speed: 8.1ms preprocess, 118.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 123.8ms
# Speed: 2.0ms preprocess, 123.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 87.6ms
# Speed: 2.4ms preprocess, 87.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 116.2ms
# Speed: 3.0ms preprocess, 116.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 128.3ms
# Speed: 3.0ms preprocess, 128.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 105.7ms
# Speed: 2.0ms preprocess, 105.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 91.5ms
# Speed: 3.0ms preprocess, 91.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 103.8ms
# Speed: 2.0ms preprocess, 103.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 110.1ms
# Speed: 3.0ms preprocess, 110.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 195.7ms
# Speed: 4.1ms preprocess, 195.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 90.3ms
# Speed: 1.4ms preprocess, 90.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 91.8ms
# Speed: 3.1ms preprocess, 91.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 165.3ms
# Speed: 4.0ms preprocess, 165.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 86.5ms
# Speed: 2.5ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 124.4ms
# Speed: 3.0ms preprocess, 124.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 130.3ms
# Speed: 2.0ms preprocess, 130.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 86.1ms
# Speed: 4.0ms preprocess, 86.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 93.8ms
# Speed: 2.4ms preprocess, 93.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 112.4ms
# Speed: 4.1ms preprocess, 112.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 141.9ms
# Speed: 3.0ms preprocess, 141.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 107.0ms
# Speed: 3.0ms preprocess, 107.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 144.1ms
# Speed: 3.0ms preprocess, 144.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 110.1ms
# Speed: 4.8ms preprocess, 110.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 92.2ms
# Speed: 3.0ms preprocess, 92.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 87.2ms
# Speed: 3.7ms preprocess, 87.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 89.1ms
# Speed: 3.0ms preprocess, 89.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 103.7ms
# Speed: 3.0ms preprocess, 103.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 105.8ms
# Speed: 48.5ms preprocess, 105.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 113.1ms
# Speed: 4.1ms preprocess, 113.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 123.3ms
# Speed: 3.2ms preprocess, 123.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 108.1ms
# Speed: 3.7ms preprocess, 108.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 85.0ms
# Speed: 3.1ms preprocess, 85.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 111.6ms
# Speed: 2.2ms preprocess, 111.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 118.2ms
# Speed: 4.0ms preprocess, 118.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 97.0ms
# Speed: 2.0ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 197.0ms
# Speed: 2.9ms preprocess, 197.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 115.0ms
# Speed: 4.1ms preprocess, 115.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 123.7ms
# Speed: 5.0ms preprocess, 123.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 89.5ms
# Speed: 2.6ms preprocess, 89.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 92.4ms
# Speed: 2.0ms preprocess, 92.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 111.0ms
# Speed: 3.0ms preprocess, 111.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 109.8ms
# Speed: 3.1ms preprocess, 109.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 90.2ms
# Speed: 3.0ms preprocess, 90.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 93.3ms
# Speed: 2.5ms preprocess, 93.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 116.3ms
# Speed: 3.0ms preprocess, 116.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 132.2ms
# Speed: 2.6ms preprocess, 132.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 96.6ms
# Speed: 3.6ms preprocess, 96.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 86.5ms
# Speed: 3.2ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 170.1ms
# Speed: 3.0ms preprocess, 170.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 126.0ms
# Speed: 18.7ms preprocess, 126.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 82.9ms
# Speed: 3.1ms preprocess, 82.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 100.8ms
# Speed: 1.5ms preprocess, 100.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 124.2ms
# Speed: 3.7ms preprocess, 124.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 89.2ms
# Speed: 3.0ms preprocess, 89.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 92.2ms
# Speed: 2.0ms preprocess, 92.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 95.3ms
# Speed: 3.0ms preprocess, 95.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 122.0ms
# Speed: 1.5ms preprocess, 122.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 94.8ms
# Speed: 4.1ms preprocess, 94.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 91.2ms
# Speed: 2.0ms preprocess, 91.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 87.9ms
# Speed: 3.0ms preprocess, 87.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 89.0ms
# Speed: 2.0ms preprocess, 89.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 99.6ms
# Speed: 3.2ms preprocess, 99.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 94.8ms
# Speed: 2.0ms preprocess, 94.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 118.3ms
# Speed: 3.1ms preprocess, 118.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 103.1ms
# Speed: 3.0ms preprocess, 103.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 115.1ms
# Speed: 4.0ms preprocess, 115.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 108.2ms
# Speed: 3.0ms preprocess, 108.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 161.7ms
# Speed: 2.1ms preprocess, 161.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 177.8ms
# Speed: 3.0ms preprocess, 177.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 86.3ms
# Speed: 3.0ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 94.5ms
# Speed: 4.6ms preprocess, 94.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 98.3ms
# Speed: 2.0ms preprocess, 98.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 128.0ms
# Speed: 3.0ms preprocess, 128.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 97.2ms
# Speed: 3.9ms preprocess, 97.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 96.0ms
# Speed: 3.1ms preprocess, 96.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 104.2ms
# Speed: 3.0ms preprocess, 104.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 102.1ms
# Speed: 3.6ms preprocess, 102.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 95.8ms
# Speed: 4.0ms preprocess, 95.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 98.4ms
# Speed: 3.0ms preprocess, 98.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 95.0ms
# Speed: 4.6ms preprocess, 95.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 137.1ms
# Speed: 42.9ms preprocess, 137.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 88.4ms
# Speed: 2.0ms preprocess, 88.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 94.0ms
# Speed: 3.1ms preprocess, 94.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 101.4ms
# Speed: 2.0ms preprocess, 101.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 99.7ms
# Speed: 4.6ms preprocess, 99.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 99.6ms
# Speed: 2.0ms preprocess, 99.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 97.6ms
# Speed: 4.5ms preprocess, 97.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 100.7ms
# Speed: 1.6ms preprocess, 100.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 112.4ms
# Speed: 3.0ms preprocess, 112.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 91.3ms
# Speed: 2.0ms preprocess, 91.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 95.4ms
# Speed: 2.5ms preprocess, 95.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 93.5ms
# Speed: 2.0ms preprocess, 93.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 101.1ms
# Speed: 2.0ms preprocess, 101.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 169.0ms
# Speed: 3.6ms preprocess, 169.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 92.0ms
# Speed: 3.1ms preprocess, 92.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 101.8ms
# Speed: 2.0ms preprocess, 101.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 87.6ms
# Speed: 3.0ms preprocess, 87.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 106.7ms
# Speed: 2.6ms preprocess, 106.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 103.7ms
# Speed: 4.3ms preprocess, 103.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 110.6ms
# Speed: 3.0ms preprocess, 110.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 105.4ms
# Speed: 2.0ms preprocess, 105.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 94.1ms
# Speed: 4.1ms preprocess, 94.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 98.4ms
# Speed: 3.0ms preprocess, 98.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 102.1ms
# Speed: 4.0ms preprocess, 102.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 91.6ms
# Speed: 4.1ms preprocess, 91.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 93.5ms
# Speed: 3.5ms preprocess, 93.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 107.5ms
# Speed: 2.4ms preprocess, 107.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 170.2ms
# Speed: 3.7ms preprocess, 170.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 88.2ms
# Speed: 2.5ms preprocess, 88.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 86.8ms
# Speed: 4.1ms preprocess, 86.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 95.8ms
# Speed: 3.4ms preprocess, 95.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 100.8ms
# Speed: 1.6ms preprocess, 100.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 89.1ms
# Speed: 4.0ms preprocess, 89.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 88.8ms
# Speed: 3.4ms preprocess, 88.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 90.0ms
# Speed: 2.6ms preprocess, 90.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 89.0ms
# Speed: 2.5ms preprocess, 89.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 96.9ms
# Speed: 3.2ms preprocess, 96.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 105.6ms
# Speed: 2.0ms preprocess, 105.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 96.1ms
# Speed: 2.0ms preprocess, 96.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 91.5ms
# Speed: 2.6ms preprocess, 91.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 106.7ms
# Speed: 74.8ms preprocess, 106.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 91.9ms
# Speed: 2.3ms preprocess, 91.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 89.4ms
# Speed: 5.7ms preprocess, 89.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 100.7ms
# Speed: 2.0ms preprocess, 100.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 95.2ms
# Speed: 3.1ms preprocess, 95.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 99.3ms
# Speed: 3.0ms preprocess, 99.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 94.7ms
# Speed: 2.5ms preprocess, 94.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 110.1ms
# Speed: 6.0ms preprocess, 110.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 98.2ms
# Speed: 3.0ms preprocess, 98.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 100.1ms
# Speed: 3.1ms preprocess, 100.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 164.8ms
# Speed: 4.6ms preprocess, 164.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 113.3ms
# Speed: 55.1ms preprocess, 113.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 94.8ms
# Speed: 1.5ms preprocess, 94.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 94.4ms
# Speed: 3.1ms preprocess, 94.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 109.4ms
# Speed: 2.0ms preprocess, 109.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 126.5ms
# Speed: 5.0ms preprocess, 126.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 145.0ms
# Speed: 6.1ms preprocess, 145.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 127.4ms
# Speed: 2.6ms preprocess, 127.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 94.0ms
# Speed: 2.0ms preprocess, 94.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 124.0ms
# Speed: 3.0ms preprocess, 124.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 154.2ms
# Speed: 7.0ms preprocess, 154.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 110.6ms
# Speed: 3.4ms preprocess, 110.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 89.4ms
# Speed: 2.6ms preprocess, 89.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 92.8ms
# Speed: 3.5ms preprocess, 92.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 83.6ms
# Speed: 3.2ms preprocess, 83.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 98.4ms
# Speed: 3.1ms preprocess, 98.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 99.6ms
# Speed: 4.1ms preprocess, 99.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 105.8ms
# Speed: 2.5ms preprocess, 105.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 186.6ms
# Speed: 4.5ms preprocess, 186.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 99.1ms
# Speed: 2.0ms preprocess, 99.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 101.4ms
# Speed: 5.1ms preprocess, 101.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 95.6ms
# Speed: 4.0ms preprocess, 95.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 111.1ms
# Speed: 3.1ms preprocess, 111.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 98.2ms
# Speed: 4.1ms preprocess, 98.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 94.1ms
# Speed: 3.0ms preprocess, 94.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 90.8ms
# Speed: 3.0ms preprocess, 90.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 101.8ms
# Speed: 3.0ms preprocess, 101.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 91.1ms
# Speed: 4.2ms preprocess, 91.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 115.9ms
# Speed: 14.2ms preprocess, 115.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 127.9ms
# Speed: 2.0ms preprocess, 127.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 177.9ms
# Speed: 4.0ms preprocess, 177.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 90.3ms
# Speed: 4.0ms preprocess, 90.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 120.4ms
# Speed: 3.0ms preprocess, 120.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 112.6ms
# Speed: 7.2ms preprocess, 112.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 193.9ms
# Speed: 4.1ms preprocess, 193.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 84.2ms
# Speed: 3.0ms preprocess, 84.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 95.3ms
# Speed: 2.4ms preprocess, 95.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 92.8ms
# Speed: 4.1ms preprocess, 92.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 91.1ms
# Speed: 2.0ms preprocess, 91.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 90.7ms
# Speed: 2.0ms preprocess, 90.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 109.4ms
# Speed: 2.0ms preprocess, 109.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 91.9ms
# Speed: 3.6ms preprocess, 91.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 94.0ms
# Speed: 3.1ms preprocess, 94.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 92.7ms
# Speed: 2.0ms preprocess, 92.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 91.9ms
# Speed: 3.0ms preprocess, 91.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 163.3ms
# Speed: 2.0ms preprocess, 163.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 84.6ms
# Speed: 3.0ms preprocess, 84.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 95.1ms
# Speed: 1.7ms preprocess, 95.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 101.7ms
# Speed: 2.0ms preprocess, 101.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 100.2ms
# Speed: 2.6ms preprocess, 100.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 103.5ms
# Speed: 3.5ms preprocess, 103.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 93.8ms
# Speed: 3.1ms preprocess, 93.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 98.0ms
# Speed: 2.0ms preprocess, 98.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 109.2ms
# Speed: 3.6ms preprocess, 109.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 96.0ms
# Speed: 5.1ms preprocess, 96.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 95.1ms
# Speed: 2.6ms preprocess, 95.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 199.4ms
# Speed: 2.0ms preprocess, 199.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 111.2ms
# Speed: 3.0ms preprocess, 111.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 99.2ms
# Speed: 4.0ms preprocess, 99.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 95.7ms
# Speed: 2.0ms preprocess, 95.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 127.2ms
# Speed: 4.1ms preprocess, 127.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 131.8ms
# Speed: 4.6ms preprocess, 131.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 131.3ms
# Speed: 4.7ms preprocess, 131.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 101.8ms
# Speed: 4.0ms preprocess, 101.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 89.7ms
# Speed: 3.0ms preprocess, 89.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 94.0ms
# Speed: 3.0ms preprocess, 94.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 148.1ms
# Speed: 3.0ms preprocess, 148.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 149.9ms
# Speed: 3.6ms preprocess, 149.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 87.9ms
# Speed: 2.0ms preprocess, 87.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 87.1ms
# Speed: 3.1ms preprocess, 87.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 86.5ms
# Speed: 3.0ms preprocess, 86.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 97.5ms
# Speed: 3.9ms preprocess, 97.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 134.2ms
# Speed: 2.3ms preprocess, 134.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 229.3ms
# Speed: 2.6ms preprocess, 229.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 134.7ms
# Speed: 3.0ms preprocess, 134.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 95.2ms
# Speed: 2.0ms preprocess, 95.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 95.2ms
# Speed: 3.1ms preprocess, 95.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 90.9ms
# Speed: 2.0ms preprocess, 90.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 102.1ms
# Speed: 3.1ms preprocess, 102.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 94.6ms
# Speed: 4.0ms preprocess, 94.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 95.2ms
# Speed: 3.0ms preprocess, 95.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 101.2ms
# Speed: 3.0ms preprocess, 101.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 97.0ms
# Speed: 5.0ms preprocess, 97.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 97.2ms
# Speed: 3.0ms preprocess, 97.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 93.6ms
# Speed: 3.0ms preprocess, 93.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 101.0ms
# Speed: 4.4ms preprocess, 101.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 101.7ms
# Speed: 4.0ms preprocess, 101.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 100.7ms
# Speed: 2.5ms preprocess, 100.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 95.1ms
# Speed: 2.6ms preprocess, 95.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 98.9ms
# Speed: 3.0ms preprocess, 98.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 103.5ms
# Speed: 2.0ms preprocess, 103.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 209.8ms
# Speed: 3.1ms preprocess, 209.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 130.0ms
# Speed: 11.9ms preprocess, 130.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 102.9ms
# Speed: 3.0ms preprocess, 102.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 97.2ms
# Speed: 4.1ms preprocess, 97.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 95.8ms
# Speed: 3.0ms preprocess, 95.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 95.2ms
# Speed: 2.6ms preprocess, 95.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 95.5ms
# Speed: 3.0ms preprocess, 95.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 99.1ms
# Speed: 7.8ms preprocess, 99.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 95.5ms
# Speed: 2.0ms preprocess, 95.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 93.3ms
# Speed: 3.1ms preprocess, 93.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 95.1ms
# Speed: 2.5ms preprocess, 95.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 98.6ms
# Speed: 3.6ms preprocess, 98.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 168.1ms
# Speed: 2.2ms preprocess, 168.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 89.9ms
# Speed: 2.6ms preprocess, 89.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 106.4ms
# Speed: 3.5ms preprocess, 106.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 93.9ms
# Speed: 4.1ms preprocess, 93.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 96.1ms
# Speed: 2.0ms preprocess, 96.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 103.6ms
# Speed: 3.1ms preprocess, 103.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 112.7ms
# Speed: 6.1ms preprocess, 112.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 95.7ms
# Speed: 3.1ms preprocess, 95.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 97.0ms
# Speed: 3.0ms preprocess, 97.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 94.2ms
# Speed: 2.0ms preprocess, 94.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 103.9ms
# Speed: 2.5ms preprocess, 103.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 100.1ms
# Speed: 3.0ms preprocess, 100.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 123.0ms
# Speed: 55.6ms preprocess, 123.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 94.3ms
# Speed: 2.5ms preprocess, 94.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 102.8ms
# Speed: 3.0ms preprocess, 102.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 92.9ms
# Speed: 2.7ms preprocess, 92.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 96.5ms
# Speed: 2.0ms preprocess, 96.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 93.8ms
# Speed: 3.0ms preprocess, 93.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 103.4ms
# Speed: 3.1ms preprocess, 103.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 90.0ms
# Speed: 4.0ms preprocess, 90.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 98.0ms
# Speed: 3.0ms preprocess, 98.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 133.3ms
# Speed: 3.4ms preprocess, 133.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 95.2ms
# Speed: 4.1ms preprocess, 95.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 104.6ms
# Speed: 4.0ms preprocess, 104.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 93.4ms
# Speed: 3.1ms preprocess, 93.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 110.3ms
# Speed: 54.7ms preprocess, 110.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 99.0ms
# Speed: 4.1ms preprocess, 99.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 98.2ms
# Speed: 1.0ms preprocess, 98.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 92.9ms
# Speed: 3.1ms preprocess, 92.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 99.1ms
# Speed: 2.7ms preprocess, 99.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 95.8ms
# Speed: 4.0ms preprocess, 95.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 97.1ms
# Speed: 2.0ms preprocess, 97.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 92.6ms
# Speed: 2.0ms preprocess, 92.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 96.4ms
# Speed: 2.1ms preprocess, 96.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 95.0ms
# Speed: 8.1ms preprocess, 95.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 187.1ms
# Speed: 2.6ms preprocess, 187.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 161.6ms
# Speed: 5.0ms preprocess, 161.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 135.9ms
# Speed: 4.0ms preprocess, 135.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 134.7ms
# Speed: 3.1ms preprocess, 134.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 148.1ms
# Speed: 6.1ms preprocess, 148.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 119.9ms
# Speed: 4.0ms preprocess, 119.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 125.3ms
# Speed: 2.0ms preprocess, 125.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 91.9ms
# Speed: 4.0ms preprocess, 91.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 100.0ms
# Speed: 2.0ms preprocess, 100.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 93.0ms
# Speed: 3.1ms preprocess, 93.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 125.3ms
# Speed: 3.0ms preprocess, 125.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 207.6ms
# Speed: 3.0ms preprocess, 207.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 96.1ms
# Speed: 3.5ms preprocess, 96.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 89.3ms
# Speed: 2.0ms preprocess, 89.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 91.1ms
# Speed: 4.1ms preprocess, 91.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 97.1ms
# Speed: 2.0ms preprocess, 97.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
cv2.destroyAllWindows()
